# %% [markdown]
# # Making behavioral/psychological file
# ## Sandra Tilmon
# ## 11/29/2023
#
#
# #### Change log:
#
# Date        Change

# %% [markdown]
# **NHANES is not available publicly at the census tract level.**

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np

import math
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats

import seaborn as sns

import os
import re
from functools import reduce
import requests

import geopandas as gpd
from shapely.geometry import shape, Point
import geopy
from geopy.extra.rate_limiter import RateLimiter
from geopy import geocoders
from geopy.geocoders import GoogleV3

from timeit import default_timer as timer

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# No scientific notation
pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

# %%
# Mount drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Raw data sources
dir = '/content/gdrive/My Drive/Sociome_Folder/Data/'
print(dir)

# Output curated datasets
curated = '/content/gdrive/My Drive/Sociome_Folder/Data Commons/Curated datasets/'
curated
# Out:
# /content/gdrive/My Drive/Sociome_Folder/Data/
# '/content/gdrive/My Drive/Sociome_Folder/Data Commons/Curated datasets/'

# %%
# Empty list to collect dataframe names

frames = []

# %% [markdown]
# # CDC

# %% [markdown]
# ## Places
#
# https://data.cdc.gov/500-Cities-Places/PLACES-Local-Data-for-Better-Health-Census-Tract-D/nw2y-v4gm/about_data
#
# https://data.cdc.gov/browse/select_dataset?q=census+tract&sortBy=relevance&tags=brfss&utf8=%E2%9C%93&page=1
#
#
#
# Accessed 12/14/2023

# %%
# places = pd.read_csv(dir + 'CDC/Places/PLACES__Local_Data_for_Better_Health__Census_Tract_Data_2022_release.csv', dtype='string')
# print(places.shape)

# # Extract census tracts starting with "17031" (Cook County)
# mask = places['LocationID'].astype(str).str.startswith("17031")
# places = places[mask]
# print(places.shape)

# places.head()
# Out:
# (2161543, 23)
# (39420, 23)
#       Year StateAbbr StateDesc CountyName CountyFIPS LocationName DataSource         Category  \
# 1798  2020        IL  Illinois       Cook      17031  17031020702      BRFSS  Health Outcomes
# 1799  2020        IL  Illinois       Cook      17031  17031040402      BRFSS  Health Outcomes
# 1800  2020        IL  Illinois       Cook      17031  17031050700      BRFSS  Health Outcomes
# 1801  2020        IL  Illinois       Cook      17031  17031051200      BRFSS  Health Outcomes
# 1802  2020        IL  Illinois       Cook      17031  17031061200      BRFSS  Health Outcomes
#
#                                       Measure Data_Value_Unit   Data_Value_Type Data_Value  \
# 1798      Stroke among adults aged >=18 years               %  Crude prevalence        3.4
# 1799      Stroke among adults aged >=18 years               %  Crude prevalence        1.0
# 1800  Depression among adults aged >=18 years               %  Crude prevalence       15.5
# 1801      Stroke among adults aged >=18 years               %  Crude prevalence        0.9
# 1802      Stroke among adults aged >=18 years               %  Crude prevalence        0.7
#
#      Data_Value_Footnote_Symbol Data_Value_Footnote Low_Confidence_Limit High_Confidence_Limit  \
# 1798                       <NA>                <NA>                  3.0                   3.8
# 1799                       <NA>                <NA>                  0.9                   1.1
# 1800                       <NA>                <NA>                 14.7                  16.4
# 1801                       <NA>                <NA>                  0.8                   1.0
# 1802                       <NA>                <NA>                  0.6                   0.8
#
#      TotalPopulation                       Geolocation   LocationID CategoryID   MeasureId  \
# 1798            7194  POINT (-87.70545142 41.99533955)  17031020702    HLTHOUT      STROKE
# 1799            4468    POINT (-87.6787372 41.9724992)  17031040402    HLTHOUT      STROKE
# 1800            1418  POINT (-87.67602892 41.94508495)  17031050700    HLTHOUT  DEPRESSION
# 1801            1516   POINT (-87.67594323 41.9414376)  17031051200    HLTHOUT      STROKE
# 1802            1889  POINT (-87.66161258 41.94908085)  17031061200    HLTHOUT      STROKE
#
#      DataValueTypeID Short_Question_Text
# 1798          CrdPrv              Stroke
# 1799          CrdPrv              Stroke
# 1800          CrdPrv          Depression
# 1801          CrdPrv              Stroke
# 1802          CrdPrv              Stroke

# %%
# pd.set_option('display.max_colwidth', None)
# places['Measure'].value_counts()
# Out:
# Stroke among adults aged >=18 years                                                                                                                                                               1314
# Depression among adults aged >=18 years                                                                                                                                                           1314
# Diagnosed diabetes among adults aged >=18 years                                                                                                                                                   1314
# Arthritis among adults aged >=18 years                                                                                                                                                            1314
# Obesity among adults aged >=18 years                                                                                                                                                              1314
# All teeth lost among adults aged >=65 years                                                                                                                                                       1314
# Mammography use among women aged 50-74 years                                                                                                                                                      1314
# No leisure-time physical activity among adults aged >=18 years                                                                                                                                    1314
# Physical health not good for >=14 days among adults aged >=18 years                                                                                                                               1314
# Current smoking among adults aged >=18 years                                                                                                                                                      1314
# Fecal occult blood test, sigmoidoscopy, or colonoscopy among adults aged 50-75 years                                                                                                              1314
# Older adult women aged >=65 years who are up to date on a core set of clinical preventive services: Flu shot past year, PPV shot ever, Colorectal cancer screening, and Mammogram past 2 years    1314
# Cholesterol screening among adults aged >=18 years                                                                                                                                                1314
# Current asthma among adults aged >=18 years                                                                                                                                                       1314
# Current lack of health insurance among adults aged 18-64 years                                                                                                                                    1314
# Visits to doctor for routine checkup within the past year among adults aged >=18 years                                                                                                            1314
# Chronic kidney disease among adults aged >=18 years                                                                                                                                               1314
# Older adult men aged >=65 years who are up to date on a core set of clinical preventive services: Flu shot past year, PPV shot ever, Colorectal cancer screening                                  1314
# Chronic obstructive pulmonary disease among adults aged >=18 years                                                                                                                                1314
# Visits to dentist or dental clinic among adults aged >=18 years                                                                                                                                   1314
# High cholesterol among adults aged >=18 years who have been screened in the past 5 years                                                                                                          1314
# Sleeping less than 7 hours among adults aged >=18 years                                                                                                                                           1314
# Taking medicine for high blood pressure control among adults aged >=18 years with high blood pressure                                                                                             1314
# Cervical cancer screening among adult women aged 21-65 years                                                                                                                                      1314
# Fair or poor self-rated health status among adults aged >=18 years                                                                                                                                1314
# High blood pressure among adults aged >=18 years                                                                                                                                                  1314
# Mental health not good for >=14 days among adults aged >=18 years                                                                                                                                 1314
# Coronary heart disease among adults aged >=18 years                                                                                                                                               1314
# Binge drinking among adults aged >=18 years                                                                                                                                                       1314
# Cancer (excluding skin cancer) among adults aged >=18 years                                                                                                                                       1314
# Name: Measure, dtype: Int64

# %%
# # Keep only behavioral/psychological measures

# places2 = places[(places['Measure'] == 'Depression among adults aged >=18 years') |
#                 (places['Measure'] == 'No leisure-time physical activity among adults aged >=18 years') |
#                 (places['Measure'] == 'Current smoking among adults aged >=18 years') |
#                 (places['Measure'] == 'Sleeping less than 7 hours among adults aged >=18 years') |
#                 (places['Measure'] == 'Mental health not good for >=14 days among adults aged >=18 years') |
#                 (places['Measure'] == 'Binge drinking among adults aged >=18 years')]

# places2 = places2[['LocationID', 'MeasureId', 'Data_Value']]

# places2.head()
# Out:
#        LocationID   MeasureId Data_Value
# 1800  17031050700  DEPRESSION       15.5
# 1809  17031080400  DEPRESSION       16.7
# 1810  17031150401  DEPRESSION       15.4
# 1811  17031230800  DEPRESSION       15.0
# 1812  17031231200  DEPRESSION       15.5

# %%
# places2['MeasureId'].value_counts()
# Out:
# DEPRESSION    1314
# LPA           1314
# CSMOKING      1314
# SLEEP         1314
# MHLTH         1314
# BINGE         1314
# Name: MeasureId, dtype: Int64

# %%
# # Pivot the DataFrame
# places3 = places2.pivot(index='LocationID', columns='MeasureId', values='Data_Value').reset_index()
# places3.head()
# Out:
# MeasureId   LocationID BINGE      CSMOKING   DEPRESSION LPA        MHLTH      SLEEP
# 0          17031010100       13.8       16.4       15.6       26.2       13.5       37.5
# 1          17031010201       13.9       20.5       16.3       32.2       14.8       38.7
# 2          17031010202       13.4       19.1       15.7       31.6       13.6       37.3
# 3          17031010300       14.2       14.5       14.7       25.3       11.9       34.1
# 4          17031010400       16.6       11.9       17.7       20.3       15.0       32.1

# %%
places3 = places3.rename(columns={'LocationID': 'GEOID10'})

# %% [markdown]
# ## Export and reload

# %%
with open(curated +  'colab63_behav_psych.csv', 'w') as f:
  places3.to_csv(f)

# %%
Behav63 = pd.read_csv(curated +  'colab63_behav_psych.csv')
Behav63=Behav63[Behav63.columns.drop(list(Behav63.filter(regex='Unnamed')))]
print(Behav63.shape)
Behav63.head()
# Out:
# (1314, 7)
#        GEOID10  BINGE  CSMOKING  DEPRESSION   LPA  MHLTH  SLEEP
# 0  17031010100  13.80     16.40       15.60 26.20  13.50  37.50
# 1  17031010201  13.90     20.50       16.30 32.20  14.80  38.70
# 2  17031010202  13.40     19.10       15.70 31.60  13.60  37.30
# 3  17031010300  14.20     14.50       14.70 25.30  11.90  34.10
# 4  17031010400  16.60     11.90       17.70 20.30  15.00  32.10

# %%
Behav63.columns.to_list()
# Out:
# ['GEOID10', 'BINGE', 'CSMOKING', 'DEPRESSION', 'LPA', 'MHLTH', 'SLEEP']
